# %%
DATA_DIR = r"D:\IntegrationXpert\male, female & kids\dataset"

# %%
from ultralytics import YOLO

model = YOLO('yolov8n-cls.pt')  # load a pretrained model (recommended for training)

model.train(data = DATA_DIR,
            epochs=20, imgsz=64)
# Out:
# ...
# 100%|██████████| 5.31M/5.31M [00:04<00:00, 1.26MB/s]
# New https://pypi.org/project/ultralytics/8.2.63 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.48  Python-3.11.9 torch-2.2.2+cpu CPU (11th Gen Intel Core(TM) i7-1185G7 3.00GHz)
# ...

# %%
from ultralytics import YOLO

model = YOLO('yolov8s-cls.pt')  # Use a small pretrained model for better performance

model.train(data=DATA_DIR,
            epochs=50,         # Increase the number of epochs
            imgsz=64)
# Out:
# ...
# 100%|██████████| 12.3M/12.3M [00:14<00:00, 905kB/s]
# New https://pypi.org/project/ultralytics/8.2.63 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.48  Python-3.11.9 torch-2.2.2+cpu CPU (11th Gen Intel Core(TM) i7-1185G7 3.00GHz)
# ...

# %%
from ultralytics import YOLO

model = YOLO('yolov8s-cls.pt')  # load a pretrained model (recommended for training)

model.train(data = DATA_DIR,
            epochs=20, imgsz=64)
# Out:
# New https://pypi.org/project/ultralytics/8.2.63 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.48  Python-3.11.9 torch-2.2.2+cpu CPU (11th Gen Intel Core(TM) i7-1185G7 3.00GHz)
# ...
